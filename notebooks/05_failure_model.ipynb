# %%
import pandas as pd
import numpy as np

latest_state = pd.read_csv(
    "../data/processed/latest_asset_state.csv"
)

maintenance = pd.read_csv(
    "../data/raw/maintenance.csv"
)

print("Latest asset state shape:", latest_state.shape)
print("Maintenance shape:", maintenance.shape)

print("\nLatest asset state columns:")
print(latest_state.columns.tolist())

print("\nMaintenance columns:")
print(maintenance.columns.tolist())
# Out:
# Latest asset state shape: (1000, 20)
# Maintenance shape: (6, 14)
#
# Latest asset state columns:
# ['asset_id', 'section_id', 'department', 'asset_type', 'snapshot_date', 'asset_age_years', 'condition_score', 'criticality', 'usage_factor', 'weather_stress', 'historical_failure_count', 'historical_downtime_hours', 'days_since_last_failure', 'failure_probability', 'failure_risk', 'condition_risk', 'criticality_risk', 'usage_risk', 'weather_risk', 'failure_history_risk']
#
# Maintenance columns:
# ['task_id', 'asset_id', 'section_id', 'department', 'maintenance_type', 'defect_type', 'severity', 'criticality', 'created_date', 'due_date', 'overdue_days', 'estimated_duration', 'required_manpower', 'status']
